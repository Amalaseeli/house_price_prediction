# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../data/processed/clean_data.csv')

# %%
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122        37                  41          880             129
# 1       -122        37                  21         7099            1106
# 2       -122        37                  52         1467             190
# 3       -122        37                  52         1274             235
# 4       -122        37                  52         1627             280
#
#    population  households  median_income  median_house_value  \
# 0         322         126              8              452600
# 1        2401        1138              8              358500
# 2         496         177              7              352100
# 3         558         219              5              341300
# 4         565         259              3              342200
#
#    ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 0                          0                       0                       0
# 1                          0                       0                       0
# 2                          0                       0                       0
# 3                          0                       0                       0
# 4                          0                       0                       0
#
#    ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN
# 0                         1                           0
# 1                         1                           0
# 2                         1                           0
# 3                         1                           0
# 4                         1                           0

# %%
X=df.drop("median_house_value", axis=1)
y=df["median_house_value"]

# %%
X.shape
# Out:
# (20640, 13)

# %%
y.shape
# Out:
# (20640,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size=0.3)
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1910        -120        39                  22         2465             539
# 11916       -117        33                  32         1979             491
# 19750       -122        40                  51         2378             584
# 12649       -121        38                  52           20               4
# 13199       -117        34                  25         1881             433
# ...          ...       ...                 ...          ...             ...
# 11498       -118        33                  14         4494            1048
# 4991        -118        33                  47         1525             359
# 1604        -122        37                  11         1077             318
# 2704        -115        32                  31         1494             289
# 18830       -123        41                  25         1941             477
#
#        population  households  median_income  ocean_proximity_<1H OCEAN  \
# 1910          381         146              2                          0
# 11916         954         444              2                          0
# 19750        1083         494              1                          0
# 12649          74           9              3                          0
# 13199        1337         417              2                          0
# ...           ...         ...            ...                        ...
# 11498        2222         963              4                          1
# 4991          982         333              2                          1
# 1604          590         264              3                          0
# 2704          959         284              3                          0
# 18830        1000         390              2                          0
#
#        ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 1910                        1                       0
# 11916                       1                       0
# 19750                       1                       0
# 12649                       1                       0
# 13199                       1                       0
# ...                       ...                     ...
# 11498                       0                       0
# 4991                        0                       0
# 1604                        0                       0
# 2704                        1                       0
# 18830                       1                       0
#
#        ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN
# 1910                          0                           0
# 11916                         0                           0
# 19750                         0                           0
# 12649                         0                           0
# 13199                         0                           0
# ...                         ...                         ...
# 11498                         0                           0
# 4991                          0                           0
# 1604                          1                           0
# 2704                          0                           0
# 18830                         0                           0
#
# [14448 rows x 13 columns]

# %%
X_train.shape
# Out:
# (14448, 13)

# %%
y_train.shape
# Out:
# (14448,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score 
from sklearn.metrics import mean_squared_error
model=LinearRegression()

# %%
model.fit(X_train,y_train)
y_train_predict=model.predict(X_train)
y_test_prediction=model.predict(X_test)

# %% [markdown]
# ## Model performance

# %%
#r2_score
train_r2_score=r2_score(y_train_predict,y_train)
test_r2_score=r2_score(y_test_prediction,y_test)

# %%
print(f"train_r2_score:{train_r2_score}, test_r2_score: {test_r2_score}")
# Out:
# train_r2_score:0.39468195336400735, test_r2_score: 0.363692549202975

# %%
#Root mean squred error 
train_rmse=float(np.sqrt(mean_squared_error(y_train_predict,y_train)))
test_rmse=float(np.sqrt(mean_squared_error(y_test_prediction,y_test)))

# %%
print(f"train_rmse:{train_rmse},  test_rmse: {test_rmse}")
# Out:
# train_rmse:70831.50458558991,  test_rmse: 70937.14129312741

# %% [markdown]
# ### Preprocessing

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_S=scaler.fit_transform(X_train)
model.fit(X_train_S, y_train)
# Out:
# LinearRegression()

# %%
y_train_predict_s=model.predict(X_train_S)
y_test_prediction=model.predict(X_test)
# Out:
# c:\Users\Thenu\Documents\amala\house_price_prediction\venv\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
train_r2_score=r2_score(y_train_predict_s,y_train)
test_r2_score=r2_score(y_test_prediction,y_test)

# %%
print(f"train_r2_score:{train_r2_score},  test_r2_score: {test_r2_score}")
# Out:
# train_r2_score:0.39431118150955247,  test_r2_score: -41.23239212497072

# %%
#Root mean squred error 
train_rmse=float(np.sqrt(mean_squared_error(y_train_predict_s,y_train)))
test_rmse=float(np.sqrt(mean_squared_error(y_test_prediction,y_test)))

# %%
print(f"train_rmse:{train_rmse},  test_rmse: {test_rmse}")
# Out:
# train_rmse:70840.4219767694,  test_rmse: 4.9222258750224e+17

# %% [markdown]
# ### Random forest Classifier

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()

# %%
forest.fit(X_train_S, y_train)
# Out:
# RandomForestRegressor()

# %%
y_train_predict_s=forest.predict(X_train_S)
y_test_prediction=forest.predict(X_test)
# Out:
# c:\Users\Thenu\Documents\amala\house_price_prediction\venv\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(

# %%
train_r2_score=r2_score(y_train_predict_s,y_train)
test_r2_score=r2_score(y_test_prediction,y_test)
print(f"train_r2_score:{train_r2_score},  test_r2_score: {test_r2_score}")
# Out:
# train_r2_score:0.9553922980099323,  test_r2_score: -14.919002149709883
